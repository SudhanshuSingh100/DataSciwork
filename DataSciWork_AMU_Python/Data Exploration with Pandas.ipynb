# %%
import pandas as pd

# %% [markdown]
# ### - Reading Files, Selecting Columns, and Summarizing

# %%
#Import Dataset
df=pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Import Dataset in generalized fashion
df=pd.read_table('train.csv',sep=',')
df.head()

# %% [markdown]
# - **examine the df data**

# %%
df           # print the first 30 and last 30 rows

# %%
type(df)     # DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()    # print the first 5 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.head(10)  # print the first 10 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
df.tail()    # print the last 5 rows
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.index     # “the index” (aka “the labels”)
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
df.columns   # column names (which is “an index”)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.dtypes    # data types of each column
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
df.shape     # number of rows and columns
# Out:
# (1460, 81)

# %%
df.values    # underlying numpy array — df are stored as numpy arrays for effeciencies.
# Out:
# array([[1, 60, 'RL', ..., 'WD', 'Normal', 208500],
#        [2, 20, 'RL', ..., 'WD', 'Normal', 181500],
#        [3, 60, 'RL', ..., 'WD', 'Normal', 223500],
#        ...,
#        [1458, 70, 'RL', ..., 'WD', 'Normal', 266500],
#        [1459, 20, 'RL', ..., 'WD', 'Normal', 142125],
#        [1460, 20, 'RL', ..., 'WD', 'Normal', 147500]], dtype=object)

# %% [markdown]
# - **select a column**

# %%
df['LotArea']         # select one column
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
# 5       14115
# 6       10084
# 7       10382
# 8        6120
# 9        7420
# 10      11200
# 11      11924
# 12      12968
# 13      10652
# 14      10920
# 15       6120
# 16      11241
# 17      10791
# 18      13695
# 19       7560
# 20      14215
# 21       7449
# 22       9742
# 23       4224
# 24       8246
# 25      14230
# 26       7200
# 27      11478
# 28      16321
# 29       6324
#         ...
# 1430    21930
# 1431     4928
# 1432    10800
# 1433    10261
# 1434    17400
# 1435     8400
# 1436     9000
# 1437    12444
# 1438     7407
# 1439    11584
# 1440    11526
# 1441     4426
# 1442    11003
# 1443     8854
# 1444     8500
# 1445     8400
# 1446    26142
# 1447    10000
# 1448    11767
# 1449     1533
# 1450     9000
# 1451     9262
# 1452     3675
# 1453    17217
# 1454     7500
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# ...

# %%
type(df['LotArea'])   # determine datatype of column (e.g., Series)
# Out:
# pandas.core.series.Series

# %%
df.LotArea            # select one column using the DataFrame attribute — not effective if column names have spaces

# %% [markdown]
# - **summarize (or describe) the DataFrame**

# %%
df.describe()          # describe all numeric columns
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.describe(include=['object']) # describe all object/character columns
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %%
df.describe(include='all')      # describe all columns
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# - **summarize a Series**

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df.LotArea.describe()   # describe a single column
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
df.LotArea.mean()       # only calculate the mean
# Out:
# 10516.828082191782

# %%
df['LotArea'].mean()    # alternate method for calculating mean
# Out:
# 10516.828082191782

# %% [markdown]
# - **count the number of occurrences of each value. group_by count**

# %%
df.MSZoning.value_counts()   # most useful for categorical variables, but can also be used with numeric variables
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %% [markdown]
# - **filter df by one column, and print out values of another column when using numeric values, no quotations**

# %%
df[df.MSZoning == 'RM'].LotArea
# Out:
# 8        6120
# 15       6120
# 21       7449
# 23       4224
# 29       6324
# 48       4456
# 51       6240
# 52       8472
# 61       7200
# 63      10300
# 68       4608
# 74       5790
# 75       1596
# 77       8635
# 79      10440
# 81       4500
# 104      7758
# 106     10800
# 107      6000
# 108      8500
# 121      6060
# 125      6780
# 127      4388
# 144      9100
# 145      2522
# 146      6120
# 149      6240
# 154     11340
# 164      5400
# 170     12358
#         ...
# 1297     3675
# 1304     3363
# 1308    12000
# 1325     3636
# 1328    10440
# 1333     7200
# 1334     2368
# 1337     4118
# 1345     6000
# 1349     5250
# 1352     6000
# 1367     2665
# 1368     4435
# 1378     1953
# 1382     7200
# 1385     5436
# 1387     8520
# 1389     6000
# 1393    10800
# 1397     6120
# 1400     6000
# 1405     3842
# 1408     7740
# 1416    11340
# 1422     4435
# 1428     7200
# 1438     7407
# 1441     4426
# 1449     1533
# 1452     3675
# ...

# %%
df[df.LotArea == 6120 ].MSZoning
# Out:
# 8       RM
# 15      RM
# 146     RM
# 584     RM
# 636     RM
# 694     RM
# 912     RM
# 1397    RM
# Name: MSZoning, dtype: object

# %%
df.shape[0]# display only the number of rows of the ‘df’ DataFrame
# Out:
# 1460

# %%
df.MSZoning.value_counts()[0:3]# display the 3 most frequent occurances of column in ‘df’
# Out:
# RL    1151
# RM     218
# FV      65
# Name: MSZoning, dtype: int64

# %% [markdown]
# ### - **Filtering and Sorting**

# %% [markdown]
# - **boolean filtering** : only show df with LotArea < 6000

# %%
filter_bool = df.LotArea < 6000    # create a Series of booleans…
filter_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1430    False
# 1431     True
# 1432    False
# 1433    False
# 1434    False
# 1435    False
# 1436    False
# 1437    False
# 1438    False
# 1439    False
# 1440    False
# 1441     True
# 1442    False
# 1443    False
# 1444    False
# 1445    False
# 1446    False
# 1447    False
# 1448    False
# 1449     True
# 1450    False
# 1451    False
# 1452     True
# 1453    False
# 1454    False
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# ...

# %%
df[filter_bool]                # …and use that Series to filter rows
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 56      57         160       FV         24.0     2645   Pave  Pave      Reg
# 68      69          30       RM         47.0     4608   Pave   NaN      Reg
# 74      75          50       RM         60.0     5790   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 81      82         120       RM         32.0     4500   Pave   NaN      Reg
# 87      88         160       FV         40.0     3951   Pave  Pave      Reg
# 115    116         160       FV         34.0     3230   Pave  Pave      Reg
# 126    127         120       RL          NaN     4928   Pave   NaN      IR1
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# ...

# %%
df[filter_bool].describe()     # describes a data frame filtered by
# Out:
#                 Id  MSSubClass  LotFrontage      LotArea  OverallQual  \
# count   193.000000  193.000000   162.000000   193.000000   193.000000
# mean    747.756477  114.196891    40.851852  3825.103627     5.937824
# std     414.493790   51.189014    17.456680  1334.103339     1.344847
# min      24.000000   20.000000    21.000000  1300.000000     1.000000
# 25%     426.000000   50.000000    24.000000  2628.000000     5.000000
# 50%     711.000000  120.000000    40.000000  4043.000000     6.000000
# 75%    1092.000000  160.000000    50.000000  5000.000000     7.000000
# max    1453.000000  190.000000   153.000000  5925.000000     9.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count   193.000000   193.000000    193.000000   192.000000   193.000000
# mean      5.533679  1973.569948   1988.404145    90.890625   358.948187
# std       1.080198    33.028973     19.820612   164.632714   377.669495
# ...

# %%
df[df.LotArea < 6000]           # or, combine into a single step
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 56      57         160       FV         24.0     2645   Pave  Pave      Reg
# 68      69          30       RM         47.0     4608   Pave   NaN      Reg
# 74      75          50       RM         60.0     5790   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 81      82         120       RM         32.0     4500   Pave   NaN      Reg
# 87      88         160       FV         40.0     3951   Pave  Pave      Reg
# 115    116         160       FV         34.0     3230   Pave  Pave      Reg
# 126    127         120       RL          NaN     4928   Pave   NaN      IR1
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# ...

# %%
df[df.LotArea < 6000].MSZoning           # select one column from the filtered results
# Out:
# 23      RM
# 48      RM
# 56      FV
# 68      RM
# 74      RM
# 75      RM
# 81      RM
# 87      FV
# 115     FV
# 126     RL
# 127     RM
# 145     RM
# 163     RL
# 164     RM
# 172     RL
# 180     FV
# 189     RL
# 193     RM
# 195     RL
# 198     RM
# 203     RM
# 204     RM
# 210     RL
# 219     RL
# 225     RM
# 227     RM
# 229     RL
# 232     RM
# 235     RM
# 241     RM
#         ..
# 1264    RH
# 1265    FV
# 1274    RL
# 1288    RL
# 1291    RM
# 1297    RM
# 1304    RM
# 1317    FV
# 1323    RL
# 1325    RM
# 1326    RH
# 1334    RM
# 1337    RM
# 1349    RM
# 1358    FV
# 1364    FV
# 1367    RM
# 1368    RM
# 1370    RL
# 1378    RM
# 1385    RM
# 1394    RL
# 1405    RM
# 1415    RL
# 1421    RL
# 1422    RM
# 1431    RL
# 1441    RM
# 1449    RM
# 1452    RM
# Name: MSZoning, Length: 193, dtype: object

# %%
# value_counts of resulting Series, can also use .mean(), etc. instead of .value_counts() for numeric variable also
df[df.LotArea < 6000].LotShape.value_counts()
# Out:
# Reg    159
# IR1     29
# IR2      4
# IR3      1
# Name: LotShape, dtype: int64

# %% [markdown]
# - **boolean filtering with multiple conditions; indexes are in square brackets, conditions are in parens**

# %%
df[(df.LotArea < 6000) & (df.LotShape=='IR1')] # ampersand for AND condition
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 126    127         120       RL          NaN     4928   Pave   NaN      IR1
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# 172    173         160       RL         44.0     5306   Pave   NaN      IR1
# 250    251          30       RL         55.0     5350   Pave   NaN      IR1
# 251    252         120       RM         44.0     4750   Pave   NaN      IR1
# 285    286         160       FV         35.0     4251   Pave  Pave      IR1
# 351    352         120       RL          NaN     5271   Pave   NaN      IR1
# 431    432          50       RM         60.0     5586   Pave   NaN      IR1
# 685    686         160       RL          NaN     5062   Pave   NaN      IR1
# 710    711          30       RL         56.0     4130   Pave   NaN      IR1
# 712    713         120       RL         40.0     4671   Pave   NaN      IR1
# ...

# %%
df[(df.LotArea < 6000) | (df.LotShape=='IR1')] # pipe for OR condition
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# ...

# %% [markdown]
# - **sorting**

# %%
df.LotArea.sort_values()          # sort a single column
# Out:
# 956       1300
# 1039      1477
# 614       1491
# 489       1526
# 1449      1533
# 1038      1533
# 75        1596
# 235       1680
# 232       1680
# 225       1680
# 430       1680
# 655       1680
# 1219      1680
# 1291      1680
# 837       1680
# 1029      1680
# 363       1680
# 227       1869
# 434       1890
# 500       1890
# 432       1920
# 649       1936
# 599       1950
# 1378      1953
# 1086      1974
# 915       2001
# 1104      2016
# 180       2117
# 623       2117
# 1358      2117
#          ...
# 876      25286
# 1383     25339
# 197      25419
# 1446     26142
# 692      26178
# 934      27650
# 828      28698
# 1057     29959
# 171      31770
# 1190     32463
# 529      32668
# 411      34650
# 1184     35133
# 1169     35760
# 1287     36500
# 271      39104
# 523      40094
# 848      45600
# 661      46589
# 53       50271
# 384      53107
# 457      53227
# 769      53504
# 1396     57200
# 1298     63887
# 451      70761
# 706     115149
# ...

# %%
df.sort_values('LotArea')   # sort a DataFrame by a single column
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 235    236         160       RM         21.0     1680   Pave   NaN      Reg
# 232    233         160       RM         21.0     1680   Pave   NaN      Reg
# 225    226         160       RM         21.0     1680   Pave   NaN      Reg
# 430    431         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %%
df.sort_values('LotArea', ascending=False)     # use descending order instead
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 457    458          20       RL          NaN    53227   Pave   NaN      IR1
# 384    385          60       RL          NaN    53107   Pave   NaN      IR2
# 53      54          20       RL         68.0    50271   Pave   NaN      IR1
# ...

# %%
df.sort_values(['LotArea','LotShape','MSZoning'],ascending=[1,1,0]) # Sort dataframe by multiple columns
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 225    226         160       RM         21.0     1680   Pave   NaN      Reg
# 232    233         160       RM         21.0     1680   Pave   NaN      Reg
# 235    236         160       RM         21.0     1680   Pave   NaN      Reg
# 363    364         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %%
# can also filter ‘df’ using pandas.Series.isin 
df[df.LotShape.isin(['Reg','IR1'])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %% [markdown]
# ### - Renaming, Adding, and Removing Columns

# %% [markdown]
# - **rename one or more columns**

# %%
df.rename(columns={'LotFrontage':'LotFrontage_N', 'Alley':'Alley_N'}, inplace=True) #saves changes
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage_N  LotArea Street Alley_N LotShape  \
# 0   1          60       RL           65.0     8450   Pave     NaN      Reg
# 1   2          20       RL           80.0     9600   Pave     NaN      Reg
# 2   3          60       RL           68.0    11250   Pave     NaN      IR1
# 3   4          70       RL           60.0     9550   Pave     NaN      IR1
# 4   5          60       RL           84.0    14260   Pave     NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# `# replace all column names (in place)
# new_cols = [‘column_x’, ‘column_y’, ‘column_z’]
# df.columns = new_cols`
#
#
# `#add a new column as a function of existing columns
# df[‘new_column_1’] = df.column_x + df.column_y`

# %%
df1=df

# %%
# removing columns
df.drop('Alley_N', axis=1)   # axis=0 for rows, 1 for columns — does not drop in place

# %%
df.drop(['Alley_N', 'MiscFeature'], axis=1, inplace=True) # drop multiple columns
df.head()

# %% [markdown]
# - **Lower-case all DataFrame column names**

# %%
df.columns = map(str.lower, df.columns)
df.columns
# Out:
# Index(['id', 'mssubclass', 'mszoning', 'lotfrontage_n', 'lotarea', 'street',
#        'alley_n', 'lotshape', 'landcontour', 'utilities', 'lotconfig',
#        'landslope', 'neighborhood', 'condition1', 'condition2', 'bldgtype',
#        'housestyle', 'overallqual', 'overallcond', 'yearbuilt', 'yearremodadd',
#        'roofstyle', 'roofmatl', 'exterior1st', 'exterior2nd', 'masvnrtype',
#        'masvnrarea', 'exterqual', 'extercond', 'foundation', 'bsmtqual',
#        'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfinsf1',
#        'bsmtfintype2', 'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'heating',
#        'heatingqc', 'centralair', 'electrical', '1stflrsf', '2ndflrsf',
#        'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath', 'fullbath',
#        'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'kitchenqual',
#        'totrmsabvgrd', 'functional', 'fireplaces', 'fireplacequ', 'garagetype',
#        'garageyrblt', 'garagefinish', 'garagecars', 'garagearea', 'garagequal',
# ...

# %% [markdown]
# - **Even more fancy DataFrame column re-naming**

# %%
# lower-case all DataFrame column names (for example)
df.rename(columns=lambda x: x.split('.')[-1], inplace=True)
df.columns

# %% [markdown]
# ### - Handling Missing Values

# %% [markdown]
# - **missing values are usually excluded by default for data analysis**

# %%
df.fence.value_counts()             # excludes missing values
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: fence, dtype: int64

# %%
df.fence.value_counts(dropna=False) # includes missing values
# Out:
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: fence, dtype: int64

# %% [markdown]
# - **find missing values in a Series**

# %%
df.fence.isnull()  # True if missing
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5       False
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17       True
# 18       True
# 19      False
# 20       True
# 21      False
# 22       True
# 23       True
# 24      False
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 1430     True
# 1431     True
# 1432     True
# 1433     True
# 1434     True
# 1435    False
# 1436    False
# 1437     True
# 1438    False
# 1439     True
# 1440     True
# 1441     True
# 1442     True
# 1443     True
# 1444     True
# 1445     True
# 1446     True
# 1447     True
# 1448    False
# 1449     True
# 1450     True
# 1451     True
# 1452     True
# 1453     True
# 1454     True
# 1455     True
# 1456    False
# 1457    False
# 1458     True
# 1459     True
# ...

# %%
df.fence.notnull() # True if not missing

# %% [markdown]
# - **use a boolean Series to filter DataFrame rows**

# %%
df[df.fence.isnull()]  # only show rows where column_x is missing
# Out:
#         id  mssubclass mszoning  lotfrontage_n  lotarea street alley_n  \
# 0        1          60       RL           65.0     8450   Pave     NaN
# 1        2          20       RL           80.0     9600   Pave     NaN
# 2        3          60       RL           68.0    11250   Pave     NaN
# 3        4          70       RL           60.0     9550   Pave     NaN
# 4        5          60       RL           84.0    14260   Pave     NaN
# 6        7          20       RL           75.0    10084   Pave     NaN
# 7        8          60       RL            NaN    10382   Pave     NaN
# 8        9          50       RM           51.0     6120   Pave     NaN
# 9       10         190       RL           50.0     7420   Pave     NaN
# 10      11          20       RL           70.0    11200   Pave     NaN
# 11      12          60       RL           85.0    11924   Pave     NaN
# 12      13          20       RL            NaN    12968   Pave     NaN
# ...

# %%
df[df.fence.notnull()] # only show rows where column_x is not missing
# Out:
#         id  mssubclass mszoning  lotfrontage_n  lotarea street alley_n  \
# 5        6          50       RL           85.0    14115   Pave     NaN
# 14      15          20       RL            NaN    10920   Pave     NaN
# 15      16          45       RM           51.0     6120   Pave     NaN
# 19      20          20       RL           70.0     7560   Pave     NaN
# 21      22          45       RM           57.0     7449   Pave    Grvl
# 24      25          20       RL            NaN     8246   Pave     NaN
# 30      31          70  C (all)           50.0     8500   Pave    Pave
# 31      32          20       RL            NaN     8544   Pave     NaN
# 40      41          20       RL           84.0     8658   Pave     NaN
# 42      43          85       RL            NaN     9180   Pave     NaN
# 43      44          20       RL            NaN     9200   Pave     NaN
# 49      50          20       RL           66.0     7742   Pave     NaN
# ...

# %% [markdown]
# - **understanding axes**

# %%
df.sum()       # sums “down” the 0 axis (rows)
# Out:
# id                                                         1066530
# mssubclass                                                   83070
# mszoning         RLRLRLRLRLRLRLRLRMRLRLRLRLRLRLRMRLRLRLRLRLRMRL...
# lotfrontage_n                                                84130
# lotarea                                                   15354569
# street           PavePavePavePavePavePavePavePavePavePavePavePa...
# lotshape         RegRegIR1IR1IR1IR1RegIR1RegRegRegIR1IR2IR1IR1R...
# landcontour      LvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlL...
# utilities        AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...
# lotconfig        InsideFR2InsideCornerFR2InsideInsideCornerInsi...
# landslope        GtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlG...
# neighborhood     CollgCrVeenkerCollgCrCrawforNoRidgeMitchelSome...
# condition1       NormFeedrNormNormNormNormNormPosNArteryArteryN...
# condition2       NormNormNormNormNormNormNormNormNormArteryNorm...
# ...

# %%
df.sum(axis=0) # equivalent (since axis=0 is the default)
# Out:
# id                                                         1066530
# mssubclass                                                   83070
# mszoning         RLRLRLRLRLRLRLRLRMRLRLRLRLRLRLRMRLRLRLRLRLRMRL...
# lotfrontage_n                                                84130
# lotarea                                                   15354569
# street           PavePavePavePavePavePavePavePavePavePavePavePa...
# lotshape         RegRegIR1IR1IR1IR1RegIR1RegRegRegIR1IR2IR1IR1R...
# landcontour      LvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlL...
# utilities        AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...
# lotconfig        InsideFR2InsideCornerFR2InsideInsideCornerInsi...
# landslope        GtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlGtlG...
# neighborhood     CollgCrVeenkerCollgCrCrawforNoRidgeMitchelSome...
# condition1       NormFeedrNormNormNormNormNormPosNArteryArteryN...
# condition2       NormNormNormNormNormNormNormNormNormArteryNorm...
# ...

# %%
df.sum(axis=1) # sums “across” the 1 axis (columns)
# Out:
# 0       231062.0
# 1       204978.0
# 2       249155.0
# 3       163499.0
# 4       280612.0
# 5       171164.0
# 6       333138.0
# 7       226556.0
# 8       150199.0
# 9       137877.0
# 10      153272.0
# 11      373337.0
# 12      169241.0
# 13      305655.0
# 14      181837.0
# 15      150301.0
# 16      173603.0
# 17      112519.0
# 18      185985.0
# 19      159618.0
# 20      356460.0
# 21      158798.0
# 22      256201.0
# 23      147262.0
# 24      175276.0
# 25      286671.0
# 26      154533.0
# 27      333531.0
# 28      238904.0
# 29       85228.0
#           ...
# 1430    229329.0
# 1431    162533.0
# 1432     88187.0
# 1433    212616.0
# 1434    192226.0
# 1435    198359.0
# 1436    142951.0
# 1437    425986.0
# 1438    172141.0
# 1439    223626.0
# 1440    219464.0
# 1441    167442.0
# 1442    337905.0
# 1443    143284.0
# 1444    204357.0
# 1445    150905.0
# 1446    198986.0
# 1447    267304.0
# 1448    137619.0
# 1449    103677.0
# 1450    158048.0
# ...

# %% [markdown]
# - **adding booleans**

# %%
pd.Series([True, False, True])       # create a boolean Series

# %%
pd.Series([True, False, True]).sum() # converts False to 0 and True to 1

# %% [markdown]
# - **find missing values in a DataFrame**

# %%
df.isnull() # DataFrame of booleans

# %%
df.isnull().sum() # count the missing values in each column

# %% [markdown]
# - **drop missing values**

# %%
# drop a row if ANY values are missing, defaults to rows, but can be applied to columns with axis=1
df.dropna(inplace=True) 
df.isnull().sum()
# Out:
# id               0
# mssubclass       0
# mszoning         0
# lotfrontage_n    0
# lotarea          0
# street           0
# alley_n          0
# lotshape         0
# landcontour      0
# utilities        0
# lotconfig        0
# landslope        0
# neighborhood     0
# condition1       0
# condition2       0
# bldgtype         0
# housestyle       0
# overallqual      0
# overallcond      0
# yearbuilt        0
# yearremodadd     0
# roofstyle        0
# roofmatl         0
# exterior1st      0
# exterior2nd      0
# masvnrtype       0
# masvnrarea       0
# exterqual        0
# extercond        0
# foundation       0
#                 ..
# bedroomabvgr     0
# kitchenabvgr     0
# kitchenqual      0
# totrmsabvgrd     0
# functional       0
# fireplaces       0
# fireplacequ      0
# garagetype       0
# garageyrblt      0
# garagefinish     0
# garagecars       0
# garagearea       0
# garagequal       0
# garagecond       0
# paveddrive       0
# wooddecksf       0
# ...

# %%
df=pd.read_csv('train.csv')
df.dropna(how='all', inplace=True)  # drop a row only if ALL values are missing
df.isnull().sum()

# %% [markdown]
# - **fill in missing values**

# %%
df.Fence.fillna(value='NA', inplace=True) 
# fill in missing values with ‘NA’
# value does not have to equal a string — can be set as some calculated value like df.column_x.mode(), or just a number like 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-8b3ea1469cf4> in <module>()
# ----> 1 df.Fence.fillna(value='NA', inplace=True)
#       2 # fill in missing values with ‘NA’
#       3 # value does not have to equal a string — can be set as some calculated value like df.column_x.mode(), or just a number like 0
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fence'

# %% [markdown]
# - **turn off the missing value filter**

# %%
df = pd.read_csv('train.csv', header=0, names=new_cols, na_filter=False)

# %% [markdown]
# ### Groupby

# %% [markdown]
# - **for each value in column_x, calculate the mean column_y**:`df.groupby(‘column_x’).column_y.mean()`

# %%
df.groupby('LotShape').LotArea.mean()

# %%
# for each value in column_x, count the number of occurrences
df.LotShape.value_counts()

# %%
# for each value in column_x, describe column_y
df.groupby('LotShape').LotArea.describe()

# %%
# similar, but outputs a DataFrame and can be customized
df.groupby('LotShape').LotArea.agg(['count', 'mean', 'min', 'max'])

# %%
df.groupby('LotShape').LotArea.agg(['count', 'mean', 'min', 'max']).sort_values('mean')

# %% [markdown]
# - if you don’t specify a column to which the aggregation function should be applied, it will be applied to all numeric columns

# %%
df.groupby('LotShape').mean()

# %%
df.groupby('LotShape').describe()

# %%
# can also groupby a list of columns, i.e., for each combination of column_x and column_y, calculate the mean column_z
df.groupby(['LotShape','MSZoning']).LotArea.mean()

# %%
#to take groupby results out of hierarchical index format (e.g., present as table), use .unstack() method
df.groupby('LotShape').LotArea.value_counts().unstack()

# %%
#conversely, if you want to transform a table into a hierarchical index, use the `.stack()` method
df.stack()

# %% [markdown]
# ### - Selecting Multiple Columns and Filtering Rows

# %%
# select multiple columns
my_cols = ['LotShape','MSZoning']  # create a list of column names…
df[my_cols]                   # …and use that list to select columns
df[['LotShape','MSZoning']]  # or, combine into a single step — double brackets due to indexing a list.

# %%
# use loc to select columns by name
df.loc[:, 'LotShape']    # colon means “all rows”, then select one column
df.loc[:, ['LotShape','MSZoning']]  # select two columns
df.loc[:, 'MSZoning':'LotShape']     # select a range of columns (i.e., selects all columns including first through last specified)

# %%
# loc can also filter rows by “name” (the index)
df.loc[0, :]       # row 0, all columns
df.loc[0:2, :]     # rows 0/1/2, all columns
df.loc[0:2, 'MSZoning':'LotShape'] # rows 0/1/2, range of columns. However, use df.ix[] for mixed use

# %%
# use iloc to filter rows and select columns by integer position
df.iloc[:, [0, 3]]     # all rows, columns in position 0/3
df.iloc[:, 0:4]        # all rows, columns in position 0/1/2/3
df.iloc[0:3, :]        # rows in position 0/1/2, all columns

# %%
#filtering out and dropping rows based on condition (e.g., where column_x values are null)
drop_rows = df[df['Fence'].isnull()]
new_df = df[~df.isin(drop_rows)].dropna(how='all')
new_df.head()

# %% [markdown]
# ### - Merging and Concatenating Dataframes

# %%
#concatenating two dfs together (just smooshes them together, does not pair them in any meaningful way) - axis=1 concats df2 to right side of df1; axis=0 concats df2 to bottom of df1
new_df = pd.concat([df1, df2], axis=1)

# %%
#merging dfs based on paired columns; columns do not need to have same name, but should match values; left_on column comes from df1, right_on column comes from df2
new_df = pd.merge(df1, df2, left_on='column_x', right_on='column_y')

# %%
#can also merge slices of dfs together, though slices need to include columns used for merging
new_df = pd.merge(df1[['column_x1', 'column_x2']], df2, left_on='column_x2', right_on='column_y')

# %%
#merging two dataframes based on shared index values (left is df1, right is df2)
new_df = pd.merge(df1, df2, left_index=True, right_index=True)
